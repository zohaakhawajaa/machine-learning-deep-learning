# %% [markdown]
# ## import Libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
import numpy as np

salary = np.array([10000, 20000, 30000, 500000])

log_salary = np.log(salary)

# %%
log_salary
# Out:
# array([ 9.21034037,  9.90348755, 10.30895266, 13.12236338])

# %%
df = pd.DataFrame({'values':[10000,20000,30000,50000]})
df
# Out:
#    values
# 0   10000
# 1   20000
# 2   30000
# 3   50000

# %%
df['log_values']= np.log(df["values"])

# %%
df["log_values"]
# Out:
# 0     9.210340
# 1     9.903488
# 2    10.308953
# 3    10.819778
# Name: log_values, dtype: float64
