# %% [markdown]
# # Import Libraries:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Label Encoder:

# %%
le = LabelEncoder()
gender = ["Male","Female","Trans"]
encoded = le.fit_transform(gender)
print(encoded)
# Out:
# [1 0 2]

# %% [markdown]
# ## One Hot Encoding:

# %%
from sklearn.preprocessing import OneHotEncoder
df = pd.DataFrame({
    "City": ["Lahore", "Karachi", "Lahore"]
})
ohe = OneHotEncoder(sparse_output=False)
encoded = ohe.fit_transform(df[["City"]])
print(encoded)
# Out:
# [[0. 1.]
#  [1. 0.]
#  [0. 1.]]

# %% [markdown]
# ## Ordinal Encoder:

# %%
from sklearn.preprocessing import OrdinalEncoder
df = pd.DataFrame({
    "Size":["Small","Medium","Large","Small","Medium"]
})
oe = OrdinalEncoder(categories=[["Small","Medium","Large"]])
encoded = oe.fit_transform(df[["Size"]])
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.]])

# %% [markdown]
# ## Feature Encoding in pandas:

# %%
import pandas as pd

df = pd.DataFrame({
    "City": ["Lahore", "Karachi", "Islamabad", "Lahore"]
})

print(df)
encoded_df = pd.get_dummies(df)
# Out:
#         City
# 0     Lahore
# 1    Karachi
# 2  Islamabad
# 3     Lahore

# %% [markdown]
# *********************************************************************************************************

# %% [markdown]
# # Python Library category_encoders:

# %%
#!pip install category_encoders

# %%
from category_encoders import BinaryEncoder

# %%
df1 = pd.DataFrame({
    "Size":["Small","Medium","Large","Small"]
})
ce = BinaryEncoder(cols=["Size"])
ce.fit_transform(df1)
# Out:
#    Size_0  Size_1
# 0       0       1
# 1       1       0
# 2       1       1
# 3       0       1

# %% [markdown]
# * # Discretization:

# %%
from sklearn.preprocessing import KBinsDiscretizer
df2 = pd.DataFrame({
    "Age":[22,25,30,35,40,45,50]
})
print(df2)
# Out:
#    Age
# 0   22
# 1   25
# 2   30
# 3   35
# 4   40
# 5   45
# 6   50

# %%
kbd = KBinsDiscretizer(n_bins=3,encode="ordinal",strategy="uniform")
df2["Age_binned"] = kbd.fit_transform(df2[["Age"]])
# Out:
# 0    0.0
# 1    0.0
# 2    0.0
# 3    1.0
# 4    1.0
# 5    2.0
# 6    2.0
# Name: Age_binned, dtype: float64

# %%
df2
# Out:
#    Age  Age_binned
# 0   22         0.0
# 1   25         0.0
# 2   30         0.0
# 3   35         1.0
# 4   40         1.0
# 5   45         2.0
# 6   50         2.0
